# %% [markdown]
# <a href="https://colab.research.google.com/github/kandkurteram/course-v3/blob/master/RamK_FirstDeepLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs=64

# %%
path = untar_data(URLs.PETS)
path
# Out:
# PosixPath('/root/.fastai/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images')]

# %%
path_img = path/'images'
path_anno = path/'annotations'

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_71.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/basset_hound_62.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_83.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_106.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/havanese_58.jpg')]

# %%
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(len(data.classes))
data.c
# Out:
# 37
# 37

# %%
learn = cnn_learner(data, models.resnet34, metrics = error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:00<00:00, 99160202.91it/s]

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.402375</td>
#       <td>0.332768</td>
#       <td>0.101489</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.560513</td>
#       <td>0.255629</td>
#       <td>0.081867</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.342344</td>
#       <td>0.208681</td>
#       <td>0.064953</td>
#       <td>01:42</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.272614</td>
#       <td>0.204767</td>
#       <td>0.067659</td>
#       <td>01:39</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
losses,idxs = interp.top_losses()

# %%
len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Ragdoll', 'Birman', 6),
#  ('Birman', 'Ragdoll', 5),
#  ('Egyptian_Mau', 'Bengal', 5),
#  ('staffordshire_bull_terrier', 'american_bulldog', 5),
#  ('British_Shorthair', 'Russian_Blue', 4),
#  ('Russian_Blue', 'British_Shorthair', 4),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 4),
#  ('Bengal', 'Abyssinian', 3),
#  ('Persian', 'Ragdoll', 3),
#  ('american_pit_bull_terrier', 'american_bulldog', 3),
#  ('miniature_pinscher', 'american_pit_bull_terrier', 3),
#  ('Abyssinian', 'Maine_Coon', 2),
#  ('Ragdoll', 'Maine_Coon', 2),
#  ('Siamese', 'Birman', 2),
#  ('Siamese', 'Bombay', 2),
#  ('american_bulldog', 'american_pit_bull_terrier', 2),
#  ('boxer', 'american_bulldog', 2),
#  ('english_setter', 'english_cocker_spaniel', 2),
#  ('german_shorthaired', 'english_setter', 2)]

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.532435</td>
#       <td>0.296178</td>
#       <td>0.092016</td>
#       <td>01:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.227874</td>
#       <td>0.199481</td>
#       <td>0.062246</td>
#       <td>01:47</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.218547</td>
#       <td>0.197718</td>
#       <td>0.062923</td>
#       <td>01:47</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1'
         )

# %%
learn.load('stage-1');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dd7d8df23976> in <module>()
# ----> 1 learn.load('stage-1');
#
# NameError: name 'learn' is not defined
